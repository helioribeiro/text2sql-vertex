# %%
import pandas as pd

# Load the Excel file into a DataFrame
excel_file = "cleaned_data.xlsx"  # Replace with the path to your Excel file
df = pd.read_excel(excel_file)

# Save the DataFrame as a CSV file
csv_file = "demo_trainer.csv"  # Replace with your desired CSV file name
df.to_csv(csv_file, index=False)

print(f"Excel file '{excel_file}' successfully converted to CSV as '{csv_file}'.")
# Out:
# Excel file 'cleaned_data.xlsx' successfully converted to CSV as 'demo_trainer.csv'.
